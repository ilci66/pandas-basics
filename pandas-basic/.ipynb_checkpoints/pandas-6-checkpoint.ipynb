# %%
import pandas as pd

# %%
pokemon = pd.read_csv("C:/Users/SAMSUNG/desktop/data-files/pokemon.csv")

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
air_quality = pd.read_csv("C:/Users/SAMSUNG/desktop/data-files/air_quality_no2.csv", index_col=0, parse_dates=True)

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
# sorting pokemon by their attack values

pokemon.sort_values(by="Attack").head()
# Out:
#        #      Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 488  440   Happiny  Normal    NaN    220  100       5        5       15
# 121  113   Chansey  Normal    NaN    450  250       5        5       35
# 230  213   Shuckle     Bug   Rock    505   20      10      230       10
# 261  242   Blissey  Normal    NaN    540  255      10       10       75
# 139  129  Magikarp   Water    NaN    200   20      10       55       15
#
#      Sp. Def  Speed  Generation  Legendary
# 488       65     30           4      False
# 121      105     50           1      False
# 230      230      5           2      False
# 261      135     55           2      False
# 139       20     80           1      False

# %%
# sorting according to the hp and defense in descending order

pokemon.sort_values(by=["HP", "Defense"], ascending=False).head()
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
#
#      Sp. Def  Speed  Generation  Legendary
# 261      135     55           2      False
# 121      105     50           1      False
# 217       58     33           2      False
# 351       45     60           3      False
# 655       45     65           5      False

# %%
grass_types = pokemon[pokemon["Type 1"] == "Grass"]

# %%
grass_types.head()
# Out:
#      #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1              Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                Ivysaur  Grass  Poison    405  60      62       63
# 2    3               Venusaur  Grass  Poison    525  80      82       83
# 3    3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 48  43                 Oddish  Grass  Poison    320  45      50       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 48       75       65     30           1      False

# %%
grass_subset = grass_types.sort_index().groupby(["Type 2"]).head()

# %%
grass_subset
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 0      1                Bulbasaur  Grass    Poison    318   45      49
# 1      2                  Ivysaur  Grass    Poison    405   60      62
# 2      3                 Venusaur  Grass    Poison    525   80      82
# 3      3    VenusaurMega Venusaur  Grass    Poison    625   80     100
# 48    43                   Oddish  Grass    Poison    320   45      50
# 110  102                Exeggcute  Grass   Psychic    325   60      40
# 111  103                Exeggutor  Grass   Psychic    520   95      95
# 122  114                  Tangela  Grass       NaN    435   65      55
# 166  152                Chikorita  Grass       NaN    318   45      49
# 167  153                  Bayleef  Grass       NaN    405   60      62
# 168  154                 Meganium  Grass       NaN    525   80      82
# 197  182                Bellossom  Grass       NaN    490   75      80
# ...

# %%
grass_subset.count()
# Out:
# #             32
# Name          32
# Type 1        32
# Type 2        27
# Total         32
# HP            32
# Attack        32
# Defense       32
# Sp. Atk       32
# Sp. Def       32
# Speed         32
# Generation    32
# Legendary     32
# dtype: int64

# %%
grass_subset.pivot(columns="Type 1", values="Type 2")
# Out:
# Type 1     Grass
# 0         Poison
# 1         Poison
# 2         Poison
# 3         Poison
# 48        Poison
# 110      Psychic
# 111      Psychic
# 122          NaN
# 166          NaN
# 167          NaN
# 168          NaN
# 197          NaN
# 202       Flying
# 203       Flying
# 204       Flying
# 275       Dragon
# 297         Dark
# 298         Dark
# 310     Fighting
# 363         Dark
# 390       Flying
# 434       Ground
# 509          Ice
# 510          Ice
# 511          Ice
# 551       Flying
# 606        Fairy
# 607        Fairy
# 658        Steel
# 659        Steel
# 701     Fighting
# 720     Fighting

# %% [markdown]
# The pivot() function is purely reshaping of the data: a single value for each index/column combination is required.

# %% [markdown]
#     Sorting by one or more columns is supported by sort_values
#
#     The pivot function is purely restructuring of the data, pivot_table supports aggregations
#
#     The reverse of pivot (long to wide format) is melt (wide to long format)
